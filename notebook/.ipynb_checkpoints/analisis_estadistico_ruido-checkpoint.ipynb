# %% [markdown]
# # Análisis estadístico de los niveles de ruido en una avenida
#
# En este notebook se presenta el análisis estadístico de los datos recabados por los sonómetros desplegados en la avenida Eje 5 Norte. La finalidad es conocer los niveles de ruido a los que se expone la población cercana. En particular, son de interés los siguientes parámetros estadísticos:
#
# * El intervalo de tiempo durante el cual el nivel de ruido acústico rebasa los 65 dB. Este parámetro lo denotaremos como $t_{65}$.
# * El tiempo entre eventos en los que el nivel de ruido rebasa los 65 dB. Este parámetro lo denotaremos como $t_e$.
# * El valor promedio del nivel de ruido cuando rebasa el umbral de 65db. Este parámetro se se denota como $L_{65}$.

# %% [markdown]
# ## Características del sistema de adquisición de niveles de ruido
#
# Se trata de una red de cuatro sonómetros desplegados en la Avenida Eje 5 Norte, al lado de la estación de Metrobús UAM Azcapotzalco. Los sonómetros midieron el nivel equivalente de ruido (Leq) cada segundo y enviaron los datos a un servidor central. Las mediciones se realizaron el día 28 de mayo, desde las 7:30 a.m. hasta el 29 de mayo a las 6:00 a.m.
#
#
# <img src="despliegue_nodos.png">

# %%
import pandas as pd

df1=pd.read_csv('dataframe_sono1.csv')
df2=pd.read_csv('dataframe_sono2.csv')
df3=pd.read_csv('dataframe_sono3.csv')
df4=pd.read_csv('dataframe_sono4.csv')
df = {'sono1':df1, 'sono2':df2, 'sono3':df3, 'sono4':df4}
for sono in df:
    df[sono]['time'] = pd.to_datetime(df[sono]['time'])

# %%
# ajuste de offset para el sonometro 3
df['sono3']['value'] = df['sono3']['value']+8
# limitar los datos hasta las 6:00 del 29 de marzo
df['sono1']=df['sono1'][(df['sono1']['time'] <= '2024-05-29 05:59:59')]

# %% [markdown]
# ## Niveles de ruido registrado
# A lo largo de esta seccion se reporta los niveles percentiels, el analisis estadistico de los niveles de ruido y de los "eventos ruidosos".
#
# La siguiente grafica muestra el promedio por hora del ruido registrado por los cuatro sonómetros, esta grafica ayuda a ver la tendencia del ruido a lo largo del dia:

# %%
# gráfica del promedio del Leq por cada hora
# agrupar los valores de cada dataframe por hora
df1_hour = df['sono1'].resample('h', on='time').mean()
df2_hour = df['sono2'].resample('h', on='time').mean()
df3_hour = df['sono3'].resample('h', on='time').mean()
df4_hour = df['sono4'].resample('h', on='time').mean()
df_hour = pd.concat([df1_hour, df2_hour, df3_hour, df4_hour], axis=1)
df_hour.columns = ['value_df1', 'value_df2', 'value_df3', 'value_df4']
df_hour['mean_value'] = df_hour.mean(axis=1, skipna=True)

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(10, 4))
ax.plot(df_hour.index, df_hour['mean_value'], '-o')
ax.set_title('Promedio de ruido por hora')
ax.set_xlabel('Hora')
ax.set_ylabel('Nivel de ruido [dBA]')
ax.grid(True)
plt.show()

# %% [markdown]
# ### Niveles percentiles
# Los niveles percentiles de ruido son métricas que ayudan a entender la variabilidad y la distribución de los niveles de ruido en un período de tiempo. Un nivel percentil, como el L10, indica que el nivel de ruido fue igual o superado durante el 10% del tiempo. De manera similar, el L50 y el L90 indican los niveles de ruido que se igualaron o superaron el 50% y el 90% del tiempo, respectivamente. Estos valores son útiles para identificar los niveles de ruido más comunes y los picos de ruido en un entorno específico.
#
# La siguiente tabla muestra los niveles percentiles de manera general:

# %%
# crear un dataframe con los niveles percentiles de cada sonometro
data = []
col = ['L10', 'L50', 'L90']
ind = []
for sono in df:
    L10 = df[sono]['value'].quantile(0.10)
    L50 = df[sono]['value'].quantile(0.50)
    L90 = df[sono]['value'].quantile(0.90)
    data.append([L10, L50, L90])
    ind.append(sono)
df_percentiles = pd.DataFrame(data, columns=col, index=ind)
df_percentiles
# Out:
#          L10    L50    L90
# sono1  53.80  64.93  72.93
# sono2  52.79  65.17  72.77
# sono3  52.04  65.17  72.82
# sono4  52.60  65.50  73.24

# %% [markdown]
# #### Horario diurno
# La siguiente tabla muestra los niveles percentiles en el horario diruno

# %%
data = []
col = ['L10', 'L50', 'L90']
ind = []
for sono in df:
    df_filtered = df[sono][(df[sono]['time']>='2024-05-28 06:00:00') & (df[sono]['time']<='2024-05-28 20:00:00')]
    L10 = df_filtered['value'].quantile(0.10)
    L50 = df_filtered['value'].quantile(0.50)
    L90 = df_filtered['value'].quantile(0.90)
    data.append([L10, L50, L90])
    ind.append(sono)
df_percentiles = pd.DataFrame(data, columns=col, index=ind)
df_percentiles
# Out:
#          L10    L50     L90
# sono1  61.49  67.32  74.440
# sono2  61.30  67.19  74.170
# sono3  61.06  67.38  74.207
# sono4  60.99  67.48  74.240

# %% [markdown]
# #### Horario nocturno
# La siguiente tabla muestra los niveles percentiles en el horario nocturno

# %%
data = []
col = ['L10', 'L50', 'L90']
ind = []
for sono in df:
    df_filtered = df[sono][(df[sono]['time']>='2024-05-28 20:00:00') & (df[sono]['time']<='2024-05-29 06:00:00')]
    L10 = df_filtered['value'].quantile(0.10)
    L50 = df_filtered['value'].quantile(0.50)
    L90 = df_filtered['value'].quantile(0.90)
    data.append([L10, L50, L90])
    ind.append(sono)
df_percentiles = pd.DataFrame(data, columns=col, index=ind)
df_percentiles
# Out:
#           L10    L50    L90
# sono1  50.349  60.42  70.48
# sono2  49.190  60.02  70.04
# sono3  47.140  58.13  68.98
# sono4  47.620  59.52  70.26

# %% [markdown]
# ### Analisis estadistico
# La siguiente tabla muestra los primeros cuatro momentos estadisticos de los niveles de ruido registrados por cada sonometro:

# %%
# Crear un data frame con los parametros estadisticos generales
data=[]
col=['Promedio', 'Varianza', 'Asimetria', 'Curtosis', 'Mediana']
ind=[]
for sono in df:
    # calcular el promedio de los niveles de ruido registrados
    avg_value = df[sono]['value'].mean()
    # desviacion estandar
    var_value = df[sono]['value'].var()
    # Asimetria
    skew_value = df[sono]['value'].skew(skipna=True)
    # curtosis
    kurt_value = df[sono]['value'].kurt(skipna=True)
    # mediana
    med_value = df[sono]['value'].median()
    data.append([avg_value, var_value, skew_value, kurt_value, med_value])
    ind.append(sono)
df_parametros_generales=pd.DataFrame(data, columns=col, index=ind)
df_parametros_generales
# Out:
#         Promedio   Varianza  Asimetria  Curtosis  Mediana
# sono1  64.352545  55.208358  -0.227750  0.192115    64.93
# sono2  64.117782  58.404493  -0.363460  0.227772    65.17
# sono3  63.936148  64.366666  -0.479235  0.164528    65.17
# sono4  64.398347  62.369934  -0.502345  0.281967    65.50

# %% [markdown]
# Las siguientes graficas muestran el histograma normalizado de los niveles de ruido recabados por cada sonometro, ademas de su PDF aproximada log-normal:

# %%
# Generacion de un histograma general para cada sonometro
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats
fig, axs = plt.subplots(2, 2, figsize=(10, 7))
sono=0
for i in range(2):
    for j in range(2):
        sono+=1
        [n, bins, patches]=axs[i, j].hist(df[f'sono{sono}']['value'], bins=40, edgecolor='k', alpha=0.6, density=True, label='Histograma normalizado')
        axs[i, j].set_title(f'Sonómetro {sono}')
        axs[i, j].set_xlabel('Leq [dBA]')
        # axs[0, 0].set_ylabel('Frecuencia')
        axs[i, j].grid(True)
        data=np.array(df[f'sono{sono}']['value'])
        # Ajustar una distribución log-normal a los datos
        shape, loc, scale = stats.lognorm.fit(data, floc=0)
        sigma = shape
        mu = np.log(scale)
        x = (bins[1:]+bins[:-1])/2
        # pdf = 1/(x*sigma*np.sqrt(2*np.pi))*np.exp(-((np.log(x)-mu)**2)/(2*sigma**2))
        pdf_fitted = stats.lognorm.pdf(x, shape, loc=loc, scale=scale)
        # error cuadratico medio
        mse = np.mean((pdf_fitted-n)**2)
        # axs[i, j].plot(x, pdf, 'g-', label='PDF ajustada', lw=4)
        axs[i, j].plot(x, pdf_fitted, 'r-', label='PDF ajustada (log-normal)', lw=2)
        axs[i, j].annotate(rf'$\mu$ = {mu:.4f} {'\n'}$\sigma$ = {sigma:.5f}', (80, 0.02))
        axs[i, j].legend()
fig.tight_layout()
plt.show()

# %%
# df general combinando a los cuatro sonometros
common_time = pd.date_range(start=min(df[sono]['time'].min() for sono in df), 
                            end=max(df[sono]['time'].max() for sono in df), 
                            freq='s')
dfs_reindexed = []
for sono in df:
    df_reindexed = df[sono].set_index('time').reindex(common_time)
    df_reindexed['time']=df_reindexed.index.to_series().interpolate() # Interpola valores faltantes
    dfs_reindexed.append(df_reindexed['value'])
df_concat = pd.concat(dfs_reindexed, axis=1)
df_concat['mean_value'] = df_concat['value'].mean(axis=1, skipna=True)
df_result = df_concat.reset_index().rename(columns={'index': 'time'})

df_general=df_result[['time', 'mean_value']]

# plt.hist(df_general['mean_value'], bins=40, edgecolor='k', alpha=0.6, density=True)
# plt.title('Histograma normalizado general')
# plt.xlabel('Leq [dBA]')
# plt.show()

# %% [markdown]
# #### Horario diurno

# %%
# Definir el rango de tiempo deseado
start_time = '2024-05-28 06:00:00'
end_time = '2024-05-28 20:00:00'

# Crear un data frame con los parametros estadisticos del periodo diurno
data=[]
col=['Promedio', 'Varianza', 'Asimetria', 'Curtosis', 'Mediana']
ind=[]
for sono in df:
    # Filtrar el DataFrame para incluir solo los datos dentro del rango de tiempo especificado
    filtered_df = df[sono][(df[sono]['time'] >= start_time) & (df[sono]['time'] <= end_time)]
    # calcular el promedio de los niveles de ruido registrados
    avg_value = filtered_df['value'].mean()
    # varianza
    var_value = filtered_df['value'].var()
    #Asimetria
    skew_value = filtered_df['value'].skew()
    # curtosis
    kurt_value = filtered_df['value'].kurt()
    # mediana
    med_value = filtered_df['value'].median()
    data.append([avg_value, var_value, skew_value, kurt_value, med_value])
    ind.append(sono)
df_parametros_diurnos=pd.DataFrame(data, columns=col, index=ind)
df_parametros_diurnos
# Out:
#         Promedio   Varianza  Asimetria  Curtosis  Mediana
# sono1  67.685384  27.737794   0.644356  1.060563    67.32
# sono2  67.540506  26.402423   0.633575  1.281298    67.19
# sono3  67.582179  27.279279   0.460328  0.766007    67.38
# sono4  67.613347  28.226340   0.400363  0.767899    67.48

# %%
import scipy.stats as stats
fig, axs = plt.subplots(2, 2, figsize=(10, 7))
sono=0
for i in range(2):
    for j in range(2):
        sono+=1
        filtered_df = df[f'sono{sono}'][(df[f'sono{sono}']['time'] >= start_time) & (df[f'sono{sono}']['time'] <= end_time)]
        [n, bins, patches]=axs[i, j].hist(filtered_df['value'], bins=40, edgecolor='k', alpha=0.6, density=True, label='Histograma normalizado')
        axs[i, j].set_title(f'Sonómetro {sono}')
        axs[i, j].set_xlabel('Leq [dBA]')
        # axs[0, 0].set_ylabel('Frecuencia')
        axs[i, j].grid(True)
        data=np.array(filtered_df['value'])
        # Ajustar una distribución log-normal a los datos
        shape, loc, scale = stats.lognorm.fit(data, floc=0)
        sigma = shape
        mu = np.log(scale)
        x = (bins[1:]+bins[:-1])/2
        # pdf = 1/(x*sigma*np.sqrt(2*np.pi))*np.exp(-((np.log(x)-mu)**2)/(2*sigma**2))
        pdf_fitted = stats.lognorm.pdf(x, shape, loc=loc, scale=scale)
        # error cuadratico medio
        mse = np.mean((pdf_fitted-n)**2)
        # axs[i, j].plot(x, pdf, 'g-', label='PDF ajustada', lw=4)
        axs[i, j].plot(x, pdf_fitted, 'r-', label='PDF ajustada (log-normal)', lw=2)
        axs[i, j].annotate(rf'$\mu$ = {mu:.4f} {'\n'}$\sigma$ = {sigma:.5f}', (90, 0.03))
        axs[i, j].legend()
fig.tight_layout()
plt.show()

# %% [markdown]
# Nivel equivalente en el horario diurno:

# %%
df_diurno=df_general[(df_general['time']>=start_time) & (df_general['time']<=end_time)]
leq_diurno = 10*np.log10(1/df_diurno['mean_value'].count()*np.sum((pow(10, df_diurno['mean_value']/10))))
leq_diurno
# Out:
# 71.2344750889663

# %% [markdown]
# #### Horario Nocturno

# %%
# Definir el rango de tiempo deseado
start_time = '2024-05-28 20:00:00'
end_time = '2024-05-29 06:00:00'

# Crear un data frame con los parametros estadisticos del periodo dnocturno
data=[]
col=['Promedio', 'Varianza', 'Asimetria', 'Curtosis', 'Mediana']
ind=[]
for sono in df:
    # Filtrar el DataFrame para incluir solo los datos dentro del rango de tiempo especificado
    filtered_df = df[sono][(df[sono]['time'] >= start_time) & (df[sono]['time'] <= end_time)]
    # calcular el promedio de los niveles de ruido registrados
    avg_value = filtered_df['value'].mean()
    # varianza
    var_value = filtered_df['value'].var()
    #Asimetria
    skew_value = filtered_df['value'].skew()
    # curtosis
    kurt_value = filtered_df['value'].kurt()
    # mediana
    med_value = filtered_df['value'].median()
    data.append([avg_value, var_value, skew_value, kurt_value, med_value])
    ind.append(sono)
df_parametros_diurnos=pd.DataFrame(data, columns=col, index=ind)
df_parametros_diurnos
# Out:
#         Promedio   Varianza  Asimetria  Curtosis  Mediana
# sono1  60.467591  59.188690   0.153762 -0.383094    60.42
# sono2  59.868368  65.533355   0.104592 -0.542120    60.02
# sono3  58.245815  69.120597   0.151136 -0.585902    58.13
# sono4  59.232425  73.936152   0.080880 -0.668841    59.52

# %%
import scipy.stats as stats
fig, axs = plt.subplots(2, 2, figsize=(10, 7))
sono=0
for i in range(2):
    for j in range(2):
        sono+=1
        filtered_df = df[f'sono{sono}'][(df[f'sono{sono}']['time'] >= start_time) & (df[f'sono{sono}']['time'] <= end_time)]
        [n, bins, patches]=axs[i, j].hist(filtered_df['value'], bins=40, edgecolor='k', alpha=0.6, density=True, label='Histograma normalizado')
        axs[i, j].set_title(f'Sonómetro {sono}')
        axs[i, j].set_xlabel('Leq [dBA]')
        # axs[0, 0].set_ylabel('Frecuencia')
        axs[i, j].grid(True)
        data=np.array(filtered_df['value'])
        # Ajustar una distribución log-normal a los datos
        shape, loc, scale = stats.lognorm.fit(data, floc=0)
        sigma = shape
        mu = np.log(scale)
        x = (bins[1:]+bins[:-1])/2
        # pdf = 1/(x*sigma*np.sqrt(2*np.pi))*np.exp(-((np.log(x)-mu)**2)/(2*sigma**2))
        pdf_fitted = stats.lognorm.pdf(x, shape, loc=loc, scale=scale)
        # error cuadratico medio
        # mse = np.mean((pdf_fitted-n)**2)
        # axs[i, j].plot(x, pdf, 'g-', label='PDF ajustada', lw=4)
        axs[i, j].plot(x, pdf_fitted, 'r-', label='PDF ajustada (log-normal)', lw=2)
        axs[i, j].annotate(rf'$\mu$ = {mu:.4f} {'\n'}$\sigma$ = {sigma:.5f}', (80, 0.03))
        axs[i, j].legend()
fig.tight_layout()
plt.show()

# %% [markdown]
# Nivel equivalente en el horario nocturno

# %%
df_nocturno=df_general[(df_general['time']>=start_time) & (df_general['time']<=end_time)]
leq_nocturno = 10*np.log10(1/df_nocturno['mean_value'].count()*np.sum((pow(10, df_nocturno['mean_value']/10))))
leq_nocturno
# Out:
# 66.49895241963117

# %% [markdown]
# ## Eventos ruidosos
# En este estudio, un "evento ruidoso" se define como una instancia en la que el nivel de ruido
# supera los 65 dB,
# un umbral considerado perjudicial para la salud auditiva.
# Se han analizado las siguientes características de estos eventos:
#
# + Duración de los eventos: La cantidad de tiempo durante el cual el nivel de ruido se mantiene por encima de los 65 dB ($t_{65}$).
# + Tiempo entre eventos: El intervalo de tiempo entre dos eventos consecutivos que superan los 65 dB ($t_e$).
# + Valor promedio de los eventos ruidosos: El valor promedio del ruido registrado durante un evento ruidoso ($n_{65}$).

# %%
# cargar los dataframes de los eventos ruidosos
df1=pd.read_csv('dataframe_eventos_sono1.csv')
df2=pd.read_csv('dataframe_eventos_sono2.csv')
df3=pd.read_csv('dataframe_eventos_sono3.csv')
df4=pd.read_csv('dataframe_eventos_sono4.csv')
df_eventos = {'sono1':df1, 'sono2':df2, 'sono3':df3, 'sono4':df4}
# df_eventos['sono1']
df_all_events = pd.concat(df_eventos, axis=0, ignore_index=True)

# %% [markdown]
# ### Duración de los eventos ruidosos
# La siguiente tabla muestra los primeros cuatro mometos estadisticos de la duracion de los eventos ruidosos ($t_{65}$):

# %%
# calculo de los primeros 4 momentos estadisticos de los eventos ruidosos
data=[]
col=['Promedio', 'Varianza', 'Asimetria', 'Curtosis']
ind=[]
for sono in df_eventos:
    # # Filtrar el DataFrame para incluir solo los datos dentro del rango de tiempo especificado
    # filtered_df = df[sono][(df[sono]['time'] >= start_time) & (df[sono]['time'] <= end_time)]
    # calcular el promedio de los niveles de ruido registrados
    mean_value = df_eventos[sono]['duration'].mean()
    # varianza
    var_value = df_eventos[sono]['duration'].var()
    # Asimetria
    skew_value = df_eventos[sono]['duration'].skew()
    # curtosis
    kurt_value = df_eventos[sono]['duration'].kurt()
    data.append([mean_value, var_value, skew_value, kurt_value])
    ind.append(sono)
df_duracion_eventos=pd.DataFrame(data, columns=col, index=ind)
df_duracion_eventos
# Out:
#         Promedio     Varianza  Asimetria   Curtosis
# sono1  19.569592   932.867218   3.560738  17.117476
# sono2  20.212566   999.981816   4.203716  26.857528
# sono3  21.923323  1071.228132   3.331716  15.131348
# sono4  21.577970  1114.844691   4.621777  37.530088

# %% [markdown]
# El histograma normalizado de la duración de los eventos ruidosos junto con la PDF ajustada (log-normal) se muestran en la siguiente figura:

# %%
fig, axs = plt.subplots(2, 2, figsize=(10, 7))

bin_width = 2
sono=0
for i in range(2):
    for j in range(2):
        sono+=1
        # Calcular los bordes de los bins
        min_data = df_eventos[f'sono{sono}']['duration'].min()
        max_data = df_eventos[f'sono{sono}']['duration'].max()
        bins = np.arange(min_data, max_data + bin_width, bin_width)
        [n, bins, patches]=axs[i,j].hist(df_eventos[f'sono{sono}']['duration'], bins=bins, edgecolor='k', alpha=0.6, density=True, label=r'Histograma normalizado ($t_{65}$)')
        data=np.array(df_eventos[f'sono{sono}']['duration'])
        shape, loc, scale = stats.lognorm.fit(data, floc=2.5)
        sigma = shape
        mu = np.log(scale)
        x = (bins[1:]+bins[:-1])/2
        pdf_fitted = stats.lognorm.pdf(x, shape, loc=loc, scale=scale)
        axs[i, j].plot(x, pdf_fitted, 'r-', label='PDF ajustada (log-normal)', lw=2)
        axs[i, j].annotate(rf'$\mu$ = {mu:.4f} {'\n'}$\sigma$ = {sigma:.5f}', (40, 0.08))
        # axs[i, j].set_title(f'Histograma normalizado\nde la duración de los eventos ruidosos\nregistrados por el sonómetro {sono}')
        axs[i, j].set_title(f'Sonometro {sono}')
        axs[i, j].set_xlabel('Tiempo [s]')
        # axs[0, 0].set_ylabel('Frecuencia')
        axs[i, j].grid(True)
        axs[i, j].set_xlim([0, 60])
        axs[i, j].legend()

fig.tight_layout()
plt.show()

# %%
from scipy.stats import lognorm
data = np.array(df_all_events['duration'])
shape, loc, scale = lognorm.fit(data, floc=2.5)
sigma = shape
mu = np.log(scale)
x= np.linspace(min(data), max(data), 300)
pdf_values = lognorm.pdf(x, shape, loc, scale)
plt.plot(x, pdf_values)
plt.hist(df_all_events['duration'], bins=bins, edgecolor='k', alpha=0.6, density=True)
plt.annotate(rf'$\mu$ = {mu:.4f} {'\n'}$\sigma$ = {sigma:.4f}', (50, 0.06))
plt.legend(['PDF aproximada', 'Histograma normalizado'])
plt.title('Duracion de los eventos ruidosos')
plt.xlabel('[s]')
plt.xlim([0, 60])
plt.show()

# %% [markdown]
# ### Valor promedio del nivel de los eventos ruidosos

# %%
data=[]
col=['Promedio', 'Varianza', 'Asimetria', 'Curtosis']
ind=[]
for sono in df_eventos:
    # # Filtrar el DataFrame para incluir solo los datos dentro del rango de tiempo especificado
    # filtered_df = df[sono][(df[sono]['time'] >= start_time) & (df[sono]['time'] <= end_time)]
    # calcular el promedio de los niveles de ruido registrados
    mean_value = df_eventos[sono]['avg_value'].mean()
    # varianza
    var_value = df_eventos[sono]['avg_value'].var()
    # asimetria
    skew_value = df_eventos[sono]['avg_value'].skew()
    # curtosis
    kurt_value = df_eventos[sono]['avg_value'].kurt()
    data.append([mean_value, var_value, skew_value, kurt_value])
    ind.append(sono)
df_duracion_eventos=pd.DataFrame(data, columns=col, index=ind)
df_duracion_eventos
# Out:
#         Promedio  Varianza  Asimetria  Curtosis
# sono1  68.840024  5.231848   0.691889  0.280611
# sono2  68.623719  4.649910   0.754866  0.688314
# sono3  68.669428  4.852844   0.757613  0.622651
# sono4  68.857056  4.792465   0.705257  0.484548

# %%
fig, axs = plt.subplots(2, 2, figsize=(10, 7))

bin_width = 0.4
sono=0
for i in range(2):
    for j in range(2):
        sono+=1
        # Calcular los bordes de los bins
        min_data = df_eventos[f'sono{sono}']['avg_value'].min()
        max_data = df_eventos[f'sono{sono}']['avg_value'].max()
        bins = np.arange(min_data, max_data + bin_width, bin_width)
        [n, bins, patches]=axs[i,j].hist(df_eventos[f'sono{sono}']['avg_value'], bins=bins, edgecolor='k', alpha=0.6, density=True, label=r'Histograma normalizado ($n_{65}$)')
        data=np.array(df_eventos[f'sono{sono}']['avg_value'])
        shape, loc, scale = stats.lognorm.fit(data)
        sigma = shape
        mu = np.log(scale)
        x = (bins[1:]+bins[:-1])/2
        pdf_fitted = stats.lognorm.pdf(x, shape, loc=loc, scale=scale)
        axs[i, j].plot(x, pdf_fitted, 'r-', label='PDF ajustada (log-normal)', lw=2)
        axs[i, j].annotate(rf'$\mu$ = {mu:.4f} {'\n'}$\sigma$ = {sigma:.5f}', (76, 0.075))
        # axs[i, j].set_title(f'Histograma normalizado\ndel valor promedio de los eventos ruidosos\nregistrados por el sonómetro {sono}')
        axs[i, j].set_title(f'Sonómetro {sono}')
        axs[i, j].set_xlabel('Leq [dBA]')
        # axs[0, 0].set_ylabel('Frecuencia')
        axs[i, j].grid(True)
        # axs[i, j].set_xlim([0, 100])
        axs[i, j].legend()

fig.tight_layout()
plt.show()

# %%
from scipy.stats import lognorm
# Parámetros mu y sigma de la distribucion log-normal del 
# valor promedio de los eventos
# df_filtered= df_all_events[(df_all_events['start_time']>='2024-05-28 06:00:00') & (df_all_events['start_time']<='2024-05-29 06:00:00')]
df_filtered=df_all_events
data = np.array(df_filtered['avg_value'])
shape, loc, scale = lognorm.fit(data, floc=64)
sigma = shape
mu = np.log(scale)

# Valores para la gráfica de la función de densidad de probabilidad (PDF)
x = np.linspace(min(data), max(data), 100)
pdf_values = lognorm.pdf(x, shape, loc, scale)
plt.plot(x, pdf_values)
plt.hist(df_filtered['avg_value'], bins=bins, edgecolor='k', alpha=0.6, density=True)
plt.title('Valor promedio de los eventos ruidosos')
plt.xlim([64, 80])
plt.legend(['PDF aproximada','Histograma normalizado'])
plt.xlabel('[dBA]')
plt.annotate(rf'$\mu$ = {mu:.4f} {'\n'}$\sigma$ = {sigma:.4f}', (76, 0.15))
plt.show()

# %% [markdown]
# ### Tiempo entre eventos ruidosos

# %%
data=[]
col=['Promedio', 'Varianza', 'Simetira', 'Curtosis']
ind=[]
for sono in df_eventos:
    # # Filtrar el DataFrame para incluir solo los datos dentro del rango de tiempo especificado
    # filtered_df = df[sono][(df[sono]['time'] >= start_time) & (df[sono]['time'] <= end_time)]
    # calcular el promedio de los niveles de ruido registrados
    mean_value = df_eventos[sono]['time_diff'].mean()
    # desviacion estandar
    var_value = df_eventos[sono]['time_diff'].var()
    # simetria
    skew_value = df_eventos[sono]['time_diff'].skew()
    # curtosis
    kurt_value = df_eventos[sono]['time_diff'].kurt()
    data.append([mean_value, var_value, skew_value, kurt_value])
    ind.append(sono)
df_duracion_eventos=pd.DataFrame(data, columns=col, index=ind)
df_duracion_eventos
# Out:
#         Promedio     Varianza  Simetira   Curtosis
# sono1  44.233091  2722.138591  3.790388  26.242545
# sono2  44.758074  2535.912060  3.187066  17.942815
# sono3  46.645367  2983.089628  3.464392  19.798392
# sono4  43.795173  2363.424893  3.240437  16.248405

# %%
pow(2722, 0.5)
# Out:
# 52.172789842982326

# %%
fig, axs = plt.subplots(2, 2, figsize=(10, 7))

bin_width = 5
sono=0
for i in range(2):
    for j in range(2):
        sono+=1
        # Calcular los bordes de los bins
        min_data = df_eventos[f'sono{sono}']['time_diff'].min()
        max_data = df_eventos[f'sono{sono}']['time_diff'].max()
        bins = np.arange(min_data, max_data + bin_width, bin_width)
        [n, bins, patches]=axs[i,j].hist(df_eventos[f'sono{sono}']['time_diff'], bins=bins, edgecolor='k', alpha=0.6, density=True, label=r't_e')
        data=np.array(df_eventos[f'sono{sono}']['time_diff'])
        shape, loc, scale = stats.lognorm.fit(data)
        sigma = shape
        mu = np.log(scale)
        # x = (bins[1:]+bins[:-1])/2
        x = np.linspace(bins[0], 200, 200)
        pdf_fitted = stats.lognorm.pdf(x, shape, loc=loc, scale=scale)
        axs[i, j].plot(x, pdf_fitted, 'r-', label='PDF ajustada (log-normal)', lw=2)
        axs[i, j].annotate(rf'$\mu$ = {mu:.4f} {'\n'}$\sigma$ = {sigma:.5f}', (150, 0.010))
        axs[i, j].set_title(f'Sonómetro {sono}')
        axs[i, j].set_xlabel('Tiempo [s]')
        # axs[0, 0].set_ylabel('Frecuencia')
        axs[i, j].grid(True)
        axs[i, j].set_xlim([0, 200])
        axs[i, j].legend()

fig.tight_layout()
plt.show()

# %%
# Parámetros mu y sigma de la distribucion log-normal del tiempo entre eventos

data = np.array(df_all_events['time_diff'])
shape, loc, scale = lognorm.fit(data, floc=2.5)
sigma = shape
mu = np.log(scale)
x= np.linspace(min(data), max(data), 600)
pdf_values = lognorm.pdf(x, shape, loc, scale)
plt.plot(x, pdf_values)
plt.hist(df_all_events['time_diff'], bins=bins, edgecolor='k', alpha=0.6, density=True)
plt.legend(['PDF aproximada', 'Histograma normalizado'])
plt.title('Tiempo entre eventos')
plt.annotate(rf'$\mu$ = {mu:.4f} {'\n'}$\sigma$ = {sigma:.4f}', (160, 0.015))
plt.xlabel('[s]')
plt.xlim([0, 200])
plt.show()
